# %%
import cv2
import matplotlib.pyplot as plt

# %%
cam = cv2.VideoCapture(2)

# %%
cam.set(cv2.CV_)

# %%
result, image = cam.read()

# %%
plt.imshow(image)
plt.show()

# %%
import face_recognition

# %%
cam = cv2.VideoCapture(1)

# %%
result, image = cam.read()

rgbimage = cv2.cvtColor(image,cv2.COLOR_BGR2RGB)

image_encoding = face_recognition.face_encodings(rgbimage)[0]

plt.imshow(image)
plt.show()

input()

result2, image2 = cam.read()

rgbimage2 = cv2.cvtColor(image,cv2.COLOR_BGR2RGB)

image_encoding2 = face_recognition.face_encodings(rgbimage2)[0]


plt.imshow(image2)
plt.show()

print(face_recognition.compare_faces([image_encoding],image_encoding2))
# Out:
# [True]

# %%
print(face_recognition.compare_faces(image_encoding[0],image_encoding2[0]))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 print(face_recognition.compare_faces(image_encoding[0],image_encoding2[0]))
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\face_recognition\api.py:226, in compare_faces(known_face_encodings, face_encoding_to_check, tolerance)
#     217 def compare_faces(known_face_encodings, face_encoding_to_check, tolerance=0.6):
#     218     """
#     219     Compare a list of face encodings against a candidate encoding to see if they match.
#     220
#    (...)
#     224     :return: A list of True/False values indicating which known_face_encodings match the face encoding to check
#     225     """
# --> 226     return list(face_distance(known_face_encodings, face_encoding_to_check) <= tolerance)
#
# ...

# %% [markdown]
# # CLEANUP
#
# MAKE SURE YOU RUN THIS CODE TO CLEANUP OPENCV!!!

# %%
cam.release()
cv2.destroyAllWindows()
